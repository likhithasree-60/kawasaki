# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import seaborn as sns
import missingno as msno 
import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv('kawasaki_disease_dataset.csv')

# %%
df.head()
# Out:
#    Patient ID Date of Diagnosis  Age at Diagnosis  Gender         Ethnicity  \
# 0       11596        2017-09-26                 6    Male         Caucasian
# 1       37960        2015-01-02                 1  Female             Asian
# 2       81187        2021-07-08                 4    Male  African American
# 3       52559        2019-11-11                 2    Male  African American
# 4       88177        2015-12-06                 8    Male  African American
#
#                   Location  Fever Duration Symptoms Laboratory Tests  \
# 0  CityA, StateZ, Country2              25    Fever         Elevated
# 1  CityC, StateX, Country2               9     Rash         Elevated
# 2  CityB, StateZ, Country2               8    Fever         Elevated
# 3  CityA, StateY, Country1              19     Rash           Normal
# 4  CityB, StateY, Country3              28     Rash           Normal
#
#   Echocardiography Treatment Approach Clinical Outcomes  \
# 0           Normal            Aspirin         Worsening
# 1           Normal            Aspirin       Improvement
# 2           Normal            Aspirin       Improvement
# 3           Normal            Aspirin         Worsening
# 4           Normal            Aspirin            Stable
#
#               Complications Follow-up Visits Long-Term Effects
# 0               Myocarditis        Scheduled              Mild
# 1               Myocarditis    Not Scheduled               NaN
# 2               Myocarditis    Not Scheduled               NaN
# 3  Coronary Artery Aneurysm    Not Scheduled            Severe
# 4              Pericarditis        Scheduled              Mild

# %%
df.tail()
# Out:
#       Patient ID Date of Diagnosis  Age at Diagnosis  Gender  Ethnicity  \
# 2747       35992        2015-10-10                15  Female      Asian
# 2748       75899        2020-10-30                10    Male  Caucasian
# 2749       51431        2017-07-19                 6  Female      Other
# 2750       59023        2020-08-02                15    Male   Hispanic
# 2751       45902        2022-10-27                 4  Female   Hispanic
#
#                      Location  Fever Duration            Symptoms  \
# 2747  CityC, StateX, Country2              23            Red Eyes
# 2748  CityC, StateZ, Country2              26               Fever
# 2749  CityA, StateY, Country1              25                Rash
# 2750  CityB, StateY, Country3              21  Swollen Hands/Feet
# 2751  CityB, StateZ, Country3              12  Swollen Hands/Feet
#
#      Laboratory Tests Echocardiography Treatment Approach Clinical Outcomes  \
# 2747           Normal         Abnormal               IVIG         Worsening
# 2748           Normal           Normal     IVIG + Aspirin            Stable
# 2749           Normal           Normal            Aspirin         Worsening
# 2750         Elevated         Abnormal            Aspirin       Improvement
# 2751         Elevated           Normal     IVIG + Aspirin            Stable
#
#      Complications Follow-up Visits Long-Term Effects
# 2747  Pericarditis        Scheduled              Mild
# 2748   Myocarditis        Scheduled              Mild
# 2749           NaN        Scheduled              Mild
# 2750  Pericarditis    Not Scheduled            Severe
# 2751  Pericarditis    Not Scheduled              Mild

# %%
df.shape
# Out:
# (2752, 15)

# %%
df.dtypes
# Out:
# Patient ID             int64
# Date of Diagnosis     object
# Age at Diagnosis       int64
# Gender                object
# Ethnicity             object
# Location              object
# Fever Duration         int64
# Symptoms              object
# Laboratory Tests      object
# Echocardiography      object
# Treatment Approach    object
# Clinical Outcomes     object
# Complications         object
# Follow-up Visits      object
# Long-Term Effects     object
# dtype: object

# %%
print("Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :")
df.info()
# Out:
# Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient ID          2752 non-null   int64
#  1   Date of Diagnosis   2752 non-null   object
#  2   Age at Diagnosis    2752 non-null   int64
#  3   Gender              2752 non-null   object
#  4   Ethnicity           2752 non-null   object
#  5   Location            2752 non-null   object
#  6   Fever Duration      2752 non-null   int64
#  7   Symptoms            2752 non-null   object
#  8   Laboratory Tests    2752 non-null   object
#  9   Echocardiography    2752 non-null   object
#  10  Treatment Approach  2752 non-null   object
#  11  Clinical Outcomes   2752 non-null   object
#  12  Complications       2083 non-null   object
#  13  Follow-up Visits    2752 non-null   object
#  14  Long-Term Effects   1850 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 322.6+ KB

# %%
print("The unique values in each and every column in our data are as below:")
df.nunique()
# Out:
# The unique values in each and every column in our data are as below:
# Patient ID            2625
# Date of Diagnosis     1880
# Age at Diagnosis        18
# Gender                   2
# Ethnicity                5
# Location                27
# Fever Duration          30
# Symptoms                 5
# Laboratory Tests         2
# Echocardiography         2
# Treatment Approach       3
# Clinical Outcomes        3
# Complications            3
# Follow-up Visits         2
# Long-Term Effects        2
# dtype: int64

# %%
print('The statistical information about our data set is as below :')
df.describe(include='all').T
# Out:
# The statistical information about our data set is as below :
#                      count unique                      top  freq         mean  \
# Patient ID          2752.0    NaN                      NaN   NaN  55549.28125
# Date of Diagnosis     2752   1880               2023-03-29     5          NaN
# Age at Diagnosis    2752.0    NaN                      NaN   NaN     9.364099
# Gender                2752      2                   Female  1415          NaN
# Ethnicity             2752      5                    Asian   607          NaN
# Location              2752     27  CityA, StateY, Country2   119          NaN
# Fever Duration      2752.0    NaN                      NaN   NaN    15.699855
# Symptoms              2752      5                     Rash   577          NaN
# Laboratory Tests      2752      2                 Elevated  1386          NaN
# Echocardiography      2752      2                   Normal  1413          NaN
# Treatment Approach    2752      3                     IVIG   933          NaN
# Clinical Outcomes     2752      3                   Stable   941          NaN
# Complications         2083      3              Myocarditis   722          NaN
# Follow-up Visits      2752      2            Not Scheduled  1418          NaN
# Long-Term Effects     1850      2                   Severe   932          NaN
#
#                              std      min      25%      50%      75%      max
# Patient ID          25910.322813  10001.0  33747.0  56249.5  77469.5  99991.0
# Date of Diagnosis            NaN      NaN      NaN      NaN      NaN      NaN
# Age at Diagnosis        5.134936      1.0      5.0      9.0     14.0     18.0
# Gender                       NaN      NaN      NaN      NaN      NaN      NaN
# Ethnicity                    NaN      NaN      NaN      NaN      NaN      NaN
# Location                     NaN      NaN      NaN      NaN      NaN      NaN
# Fever Duration          8.608621      1.0      8.0     16.0     23.0     30.0
# Symptoms                     NaN      NaN      NaN      NaN      NaN      NaN
# Laboratory Tests             NaN      NaN      NaN      NaN      NaN      NaN
# Echocardiography             NaN      NaN      NaN      NaN      NaN      NaN
# Treatment Approach           NaN      NaN      NaN      NaN      NaN      NaN
# Clinical Outcomes            NaN      NaN      NaN      NaN      NaN      NaN
# Complications                NaN      NaN      NaN      NaN      NaN      NaN
# Follow-up Visits             NaN      NaN      NaN      NaN      NaN      NaN
# Long-Term Effects            NaN      NaN      NaN      NaN      NaN      NaN

# %%
df.isnull().sum()
# Out:
# Patient ID              0
# Date of Diagnosis       0
# Age at Diagnosis        0
# Gender                  0
# Ethnicity               0
# Location                0
# Fever Duration          0
# Symptoms                0
# Laboratory Tests        0
# Echocardiography        0
# Treatment Approach      0
# Clinical Outcomes       0
# Complications         669
# Follow-up Visits        0
# Long-Term Effects     902
# dtype: int64

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index',y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
print("Here are the columnn names of our data set :")
df.columns
# Out:
# Here are the columnn names of our data set :
# Index(['Patient ID', 'Date of Diagnosis', 'Age at Diagnosis', 'Gender',
#        'Ethnicity', 'Location', 'Fever Duration', 'Symptoms',
#        'Laboratory Tests', 'Echocardiography', 'Treatment Approach',
#        'Clinical Outcomes', 'Complications', 'Follow-up Visits',
#        'Long-Term Effects'],
#       dtype='object')

# %%
df
# Out:
#       Patient ID Date of Diagnosis  Age at Diagnosis  Gender  \
# 0          11596        2017-09-26                 6    Male
# 1          37960        2015-01-02                 1  Female
# 2          81187        2021-07-08                 4    Male
# 3          52559        2019-11-11                 2    Male
# 4          88177        2015-12-06                 8    Male
# ...          ...               ...               ...     ...
# 2747       35992        2015-10-10                15  Female
# 2748       75899        2020-10-30                10    Male
# 2749       51431        2017-07-19                 6  Female
# 2750       59023        2020-08-02                15    Male
# 2751       45902        2022-10-27                 4  Female
#
#              Ethnicity                 Location  Fever Duration  \
# 0            Caucasian  CityA, StateZ, Country2              25
# 1                Asian  CityC, StateX, Country2               9
# 2     African American  CityB, StateZ, Country2               8
# 3     African American  CityA, StateY, Country1              19
# 4     African American  CityB, StateY, Country3              28
# ...                ...                      ...             ...
# 2747             Asian  CityC, StateX, Country2              23
# 2748         Caucasian  CityC, StateZ, Country2              26
# 2749             Other  CityA, StateY, Country1              25
# 2750          Hispanic  CityB, StateY, Country3              21
# 2751          Hispanic  CityB, StateZ, Country3              12
#
#                 Symptoms Laboratory Tests Echocardiography Treatment Approach  \
# 0                  Fever         Elevated           Normal            Aspirin
# 1                   Rash         Elevated           Normal            Aspirin
# 2                  Fever         Elevated           Normal            Aspirin
# 3                   Rash           Normal           Normal            Aspirin
# 4                   Rash           Normal           Normal            Aspirin
# ...                  ...              ...              ...                ...
# 2747            Red Eyes           Normal         Abnormal               IVIG
# 2748               Fever           Normal           Normal     IVIG + Aspirin
# 2749                Rash           Normal           Normal            Aspirin
# 2750  Swollen Hands/Feet         Elevated         Abnormal            Aspirin
# 2751  Swollen Hands/Feet         Elevated           Normal     IVIG + Aspirin
#
#      Clinical Outcomes             Complications Follow-up Visits  \
# 0            Worsening               Myocarditis        Scheduled
# 1          Improvement               Myocarditis    Not Scheduled
# 2          Improvement               Myocarditis    Not Scheduled
# 3            Worsening  Coronary Artery Aneurysm    Not Scheduled
# 4               Stable              Pericarditis        Scheduled
# ...                ...                       ...              ...
# 2747         Worsening              Pericarditis        Scheduled
# 2748            Stable               Myocarditis        Scheduled
# 2749         Worsening                       NaN        Scheduled
# 2750       Improvement              Pericarditis    Not Scheduled
# 2751            Stable              Pericarditis    Not Scheduled
#
#      Long-Term Effects
# 0                 Mild
# 1                  NaN
# 2                  NaN
# 3               Severe
# 4                 Mild
# ...                ...
# 2747              Mild
# 2748              Mild
# 2749              Mild
# 2750            Severe
# 2751              Mild
#
# [2752 rows x 15 columns]

# %%
# generates a missing value matrix plot to visualize the presence of missing data in the DataFrame
msno.matrix(df)
plt.show()

# %%
df.dtypes
# Out:
# Patient ID             int64
# Date of Diagnosis     object
# Age at Diagnosis       int64
# Gender                object
# Ethnicity             object
# Location              object
# Fever Duration         int64
# Symptoms              object
# Laboratory Tests      object
# Echocardiography      object
# Treatment Approach    object
# Clinical Outcomes     object
# Complications         object
# Follow-up Visits      object
# Long-Term Effects     object
# dtype: object

# %%
print("After the null value imputation the number of missing value count is :")
df.isnull().sum()
# Out:
# After the null value imputation the number of missing value count is :
# Patient ID              0
# Date of Diagnosis       0
# Age at Diagnosis        0
# Gender                  0
# Ethnicity               0
# Location                0
# Fever Duration          0
# Symptoms                0
# Laboratory Tests        0
# Echocardiography        0
# Treatment Approach      0
# Clinical Outcomes       0
# Complications         669
# Follow-up Visits        0
# Long-Term Effects     902
# dtype: int64

# %%
df.shape
# Out:
# (2752, 15)

# %%
df.columns
# Out:
# Index(['Patient ID', 'Date of Diagnosis', 'Age at Diagnosis', 'Gender',
#        'Ethnicity', 'Location', 'Fever Duration', 'Symptoms',
#        'Laboratory Tests', 'Echocardiography', 'Treatment Approach',
#        'Clinical Outcomes', 'Complications', 'Follow-up Visits',
#        'Long-Term Effects'],
#       dtype='object')

# %%
df.drop('Patient ID',axis=1 , inplace=True)

# %%
df.drop('Date of Diagnosis',axis=1 , inplace=True)

# %%
df.shape
# Out:
# (2752, 13)

# %%
df
# Out:
#       Age at Diagnosis  Gender         Ethnicity                 Location  \
# 0                    6    Male         Caucasian  CityA, StateZ, Country2
# 1                    1  Female             Asian  CityC, StateX, Country2
# 2                    4    Male  African American  CityB, StateZ, Country2
# 3                    2    Male  African American  CityA, StateY, Country1
# 4                    8    Male  African American  CityB, StateY, Country3
# ...                ...     ...               ...                      ...
# 2747                15  Female             Asian  CityC, StateX, Country2
# 2748                10    Male         Caucasian  CityC, StateZ, Country2
# 2749                 6  Female             Other  CityA, StateY, Country1
# 2750                15    Male          Hispanic  CityB, StateY, Country3
# 2751                 4  Female          Hispanic  CityB, StateZ, Country3
#
#       Fever Duration            Symptoms Laboratory Tests Echocardiography  \
# 0                 25               Fever         Elevated           Normal
# 1                  9                Rash         Elevated           Normal
# 2                  8               Fever         Elevated           Normal
# 3                 19                Rash           Normal           Normal
# 4                 28                Rash           Normal           Normal
# ...              ...                 ...              ...              ...
# 2747              23            Red Eyes           Normal         Abnormal
# 2748              26               Fever           Normal           Normal
# 2749              25                Rash           Normal           Normal
# 2750              21  Swollen Hands/Feet         Elevated         Abnormal
# 2751              12  Swollen Hands/Feet         Elevated           Normal
#
#      Treatment Approach Clinical Outcomes             Complications  \
# 0               Aspirin         Worsening               Myocarditis
# 1               Aspirin       Improvement               Myocarditis
# 2               Aspirin       Improvement               Myocarditis
# 3               Aspirin         Worsening  Coronary Artery Aneurysm
# 4               Aspirin            Stable              Pericarditis
# ...                 ...               ...                       ...
# 2747               IVIG         Worsening              Pericarditis
# 2748     IVIG + Aspirin            Stable               Myocarditis
# 2749            Aspirin         Worsening                       NaN
# 2750            Aspirin       Improvement              Pericarditis
# 2751     IVIG + Aspirin            Stable              Pericarditis
#
#      Follow-up Visits Long-Term Effects
# 0           Scheduled              Mild
# 1       Not Scheduled               NaN
# 2       Not Scheduled               NaN
# 3       Not Scheduled            Severe
# 4           Scheduled              Mild
# ...               ...               ...
# 2747        Scheduled              Mild
# 2748        Scheduled              Mild
# 2749        Scheduled              Mild
# 2750    Not Scheduled            Severe
# 2751    Not Scheduled              Mild
#
# [2752 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df['Ethnicity'] = le.fit_transform(df['Ethnicity'])
df['Location'] = le.fit_transform(df['Location'])
df['Symptoms'] = le.fit_transform(df['Symptoms'])
df['Laboratory Tests'] = le.fit_transform(df['Laboratory Tests'])
df['Echocardiography'] = le.fit_transform(df['Echocardiography'])
df['Treatment Approach'] = le.fit_transform(df['Treatment Approach'])
df['Clinical Outcomes'] = le.fit_transform(df['Clinical Outcomes'])
df['Complications'] = le.fit_transform(df['Complications'])
df['Follow-up Visits'] = le.fit_transform(df['Follow-up Visits'])
df['Long-Term Effects'] = le.fit_transform(df['Long-Term Effects'])

# %%
df.head()
# Out:
#    Age at Diagnosis  Gender  Ethnicity  Location  Fever Duration  Symptoms  \
# 0                 6       1          2         7              25         0
# 1                 1       0          1        19               9         1
# 2                 4       1          0        16               8         0
# 3                 2       1          0         3              19         1
# 4                 8       1          0        14              28         1
#
#    Laboratory Tests  Echocardiography  Treatment Approach  Clinical Outcomes  \
# 0                 0                 1                   0                  2
# 1                 0                 1                   0                  0
# 2                 0                 1                   0                  0
# 3                 1                 1                   0                  2
# 4                 1                 1                   0                  1
#
#    Complications  Follow-up Visits  Long-Term Effects
# 0              1                 1                  0
# 1              1                 0                  2
# 2              1                 0                  2
# 3              0                 0                  1
# 4              2                 1                  0

# %%
df['Complications']=df['Complications'].fillna(df['Complications'].mean())
df['Long-Term Effects']=df['Long-Term Effects'].fillna(df['Long-Term Effects'].mean())

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index',y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
df.isnull().sum()
# Out:
# Age at Diagnosis      0
# Gender                0
# Ethnicity             0
# Location              0
# Fever Duration        0
# Symptoms              0
# Laboratory Tests      0
# Echocardiography      0
# Treatment Approach    0
# Clinical Outcomes     0
# Complications         0
# Follow-up Visits      0
# Long-Term Effects     0
# dtype: int64

# %%
df.dtypes
# Out:
# Age at Diagnosis      int64
# Gender                int32
# Ethnicity             int32
# Location              int32
# Fever Duration        int64
# Symptoms              int32
# Laboratory Tests      int32
# Echocardiography      int32
# Treatment Approach    int32
# Clinical Outcomes     int32
# Complications         int32
# Follow-up Visits      int32
# Long-Term Effects     int32
# dtype: object

# %%
#check details about the data set
print("Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :")
df.info()
# Out:
# Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age at Diagnosis    2752 non-null   int64
#  1   Gender              2752 non-null   int32
#  2   Ethnicity           2752 non-null   int32
#  3   Location            2752 non-null   int32
#  4   Fever Duration      2752 non-null   int64
#  5   Symptoms            2752 non-null   int32
#  6   Laboratory Tests    2752 non-null   int32
#  7   Echocardiography    2752 non-null   int32
#  8   Treatment Approach  2752 non-null   int32
#  9   Clinical Outcomes   2752 non-null   int32
#  10  Complications       2752 non-null   int32
#  11  Follow-up Visits    2752 non-null   int32
#  12  Long-Term Effects   2752 non-null   int32
# dtypes: int32(11), int64(2)
# memory usage: 161.4 KB

# %%
## plot the Correlation matrix
plt.figure(figsize=(17,8))
correlation=df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr = df.corr()

# %%
corr
# Out:
#                     Age at Diagnosis    Gender  Ethnicity  Location  \
# Age at Diagnosis            1.000000  0.016739  -0.008312  0.002235
# Gender                      0.016739  1.000000  -0.020776 -0.007116
# Ethnicity                  -0.008312 -0.020776   1.000000 -0.000927
# Location                    0.002235 -0.007116  -0.000927  1.000000
# Fever Duration             -0.012066 -0.020670  -0.001654  0.040389
# Symptoms                   -0.016215 -0.006103   0.013000 -0.001280
# Laboratory Tests           -0.004156 -0.006750  -0.012987  0.022617
# Echocardiography           -0.011537  0.022582  -0.017917  0.019182
# Treatment Approach          0.007654 -0.007842  -0.028613 -0.006116
# Clinical Outcomes          -0.037069 -0.025202   0.016807 -0.008349
# Complications              -0.022953 -0.001346  -0.010661 -0.023151
# Follow-up Visits            0.019443 -0.017596   0.020306  0.012093
# Long-Term Effects          -0.004889 -0.001991   0.007542 -0.002925
#
#                     Fever Duration  Symptoms  Laboratory Tests  \
# Age at Diagnosis         -0.012066 -0.016215         -0.004156
# Gender                   -0.020670 -0.006103         -0.006750
# Ethnicity                -0.001654  0.013000         -0.012987
# Location                  0.040389 -0.001280          0.022617
# Fever Duration            1.000000  0.018864         -0.039264
# Symptoms                  0.018864  1.000000         -0.008761
# Laboratory Tests         -0.039264 -0.008761          1.000000
# Echocardiography          0.000347 -0.006820          0.009647
# Treatment Approach        0.016841 -0.007599          0.003961
# Clinical Outcomes        -0.028568 -0.002593         -0.001256
# Complications            -0.005160  0.024124         -0.012848
# Follow-up Visits          0.018787 -0.013335          0.020137
# Long-Term Effects         0.021607  0.001297          0.023184
#
#                     Echocardiography  Treatment Approach  Clinical Outcomes  \
# Age at Diagnosis           -0.011537            0.007654          -0.037069
# Gender                      0.022582           -0.007842          -0.025202
# Ethnicity                  -0.017917           -0.028613           0.016807
# Location                    0.019182           -0.006116          -0.008349
# Fever Duration              0.000347            0.016841          -0.028568
# Symptoms                   -0.006820           -0.007599          -0.002593
# Laboratory Tests            0.009647            0.003961          -0.001256
# Echocardiography            1.000000            0.003358          -0.000773
# Treatment Approach          0.003358            1.000000          -0.016428
# Clinical Outcomes          -0.000773           -0.016428           1.000000
# Complications               0.017812            0.006269           0.034311
# Follow-up Visits            0.005913           -0.013227          -0.003664
# Long-Term Effects          -0.014112           -0.026993           0.009451
#
#                     Complications  Follow-up Visits  Long-Term Effects
# Age at Diagnosis        -0.022953          0.019443          -0.004889
# Gender                  -0.001346         -0.017596          -0.001991
# Ethnicity               -0.010661          0.020306           0.007542
# Location                -0.023151          0.012093          -0.002925
# Fever Duration          -0.005160          0.018787           0.021607
# Symptoms                 0.024124         -0.013335           0.001297
# Laboratory Tests        -0.012848          0.020137           0.023184
# Echocardiography         0.017812          0.005913          -0.014112
# Treatment Approach       0.006269         -0.013227          -0.026993
# Clinical Outcomes        0.034311         -0.003664           0.009451
# Complications            1.000000         -0.000360           0.004042
# Follow-up Visits        -0.000360          1.000000           0.021240
# Long-Term Effects        0.004042          0.021240           1.000000

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()

# %%
corr_matrix
# Out:
#                     Age at Diagnosis    Gender  Ethnicity  Location  \
# Age at Diagnosis            1.000000  0.016739   0.008312  0.002235
# Gender                      0.016739  1.000000   0.020776  0.007116
# Ethnicity                   0.008312  0.020776   1.000000  0.000927
# Location                    0.002235  0.007116   0.000927  1.000000
# Fever Duration              0.012066  0.020670   0.001654  0.040389
# Symptoms                    0.016215  0.006103   0.013000  0.001280
# Laboratory Tests            0.004156  0.006750   0.012987  0.022617
# Echocardiography            0.011537  0.022582   0.017917  0.019182
# Treatment Approach          0.007654  0.007842   0.028613  0.006116
# Clinical Outcomes           0.037069  0.025202   0.016807  0.008349
# Complications               0.022953  0.001346   0.010661  0.023151
# Follow-up Visits            0.019443  0.017596   0.020306  0.012093
# Long-Term Effects           0.004889  0.001991   0.007542  0.002925
#
#                     Fever Duration  Symptoms  Laboratory Tests  \
# Age at Diagnosis          0.012066  0.016215          0.004156
# Gender                    0.020670  0.006103          0.006750
# Ethnicity                 0.001654  0.013000          0.012987
# Location                  0.040389  0.001280          0.022617
# Fever Duration            1.000000  0.018864          0.039264
# Symptoms                  0.018864  1.000000          0.008761
# Laboratory Tests          0.039264  0.008761          1.000000
# Echocardiography          0.000347  0.006820          0.009647
# Treatment Approach        0.016841  0.007599          0.003961
# Clinical Outcomes         0.028568  0.002593          0.001256
# Complications             0.005160  0.024124          0.012848
# Follow-up Visits          0.018787  0.013335          0.020137
# Long-Term Effects         0.021607  0.001297          0.023184
#
#                     Echocardiography  Treatment Approach  Clinical Outcomes  \
# Age at Diagnosis            0.011537            0.007654           0.037069
# Gender                      0.022582            0.007842           0.025202
# Ethnicity                   0.017917            0.028613           0.016807
# Location                    0.019182            0.006116           0.008349
# Fever Duration              0.000347            0.016841           0.028568
# Symptoms                    0.006820            0.007599           0.002593
# Laboratory Tests            0.009647            0.003961           0.001256
# Echocardiography            1.000000            0.003358           0.000773
# Treatment Approach          0.003358            1.000000           0.016428
# Clinical Outcomes           0.000773            0.016428           1.000000
# Complications               0.017812            0.006269           0.034311
# Follow-up Visits            0.005913            0.013227           0.003664
# Long-Term Effects           0.014112            0.026993           0.009451
#
#                     Complications  Follow-up Visits  Long-Term Effects
# Age at Diagnosis         0.022953          0.019443           0.004889
# Gender                   0.001346          0.017596           0.001991
# Ethnicity                0.010661          0.020306           0.007542
# Location                 0.023151          0.012093           0.002925
# Fever Duration           0.005160          0.018787           0.021607
# Symptoms                 0.024124          0.013335           0.001297
# Laboratory Tests         0.012848          0.020137           0.023184
# Echocardiography         0.017812          0.005913           0.014112
# Treatment Approach       0.006269          0.013227           0.026993
# Clinical Outcomes        0.034311          0.003664           0.009451
# Complications            1.000000          0.000360           0.004042
# Follow-up Visits         0.000360          1.000000           0.021240
# Long-Term Effects        0.004042          0.021240           1.000000

# %%
df.hist(figsize = (14,12)) #shows graphically the value counts of each column
# Out:
# array([[<Axes: title={'center': 'Age at Diagnosis'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Ethnicity'}>,
#         <Axes: title={'center': 'Location'}>],
#        [<Axes: title={'center': 'Fever Duration'}>,
#         <Axes: title={'center': 'Symptoms'}>,
#         <Axes: title={'center': 'Laboratory Tests'}>,
#         <Axes: title={'center': 'Echocardiography'}>],
#        [<Axes: title={'center': 'Treatment Approach'}>,
#         <Axes: title={'center': 'Clinical Outcomes'}>,
#         <Axes: title={'center': 'Complications'}>,
#         <Axes: title={'center': 'Follow-up Visits'}>],
#        [<Axes: title={'center': 'Long-Term Effects'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# #### **K-Means Clustering**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X = df

# %%
X
# Out:
#       Age at Diagnosis  Gender  Ethnicity  Location  Fever Duration  Symptoms  \
# 0                    6       1          2         7              25         0
# 1                    1       0          1        19               9         1
# 2                    4       1          0        16               8         0
# 3                    2       1          0         3              19         1
# 4                    8       1          0        14              28         1
# ...                ...     ...        ...       ...             ...       ...
# 2747                15       0          1        19              23         2
# 2748                10       1          2        25              26         0
# 2749                 6       0          4         3              25         1
# 2750                15       1          3        14              21         3
# 2751                 4       0          3        17              12         3
#
#       Laboratory Tests  Echocardiography  Treatment Approach  \
# 0                    0                 1                   0
# 1                    0                 1                   0
# 2                    0                 1                   0
# 3                    1                 1                   0
# 4                    1                 1                   0
# ...                ...               ...                 ...
# 2747                 1                 0                   1
# 2748                 1                 1                   2
# 2749                 1                 1                   0
# 2750                 0                 0                   0
# 2751                 0                 1                   2
#
#       Clinical Outcomes  Complications  Follow-up Visits  Long-Term Effects
# 0                     2              1                 1                  0
# 1                     0              1                 0                  2
# 2                     0              1                 0                  2
# 3                     2              0                 0                  1
# 4                     1              2                 1                  0
# ...                 ...            ...               ...                ...
# 2747                  2              2                 1                  0
# 2748                  1              1                 1                  0
# 2749                  2              3                 1                  0
# 2750                  0              2                 0                  1
# 2751                  1              2                 0                  0
#
# [2752 rows x 13 columns]

# %%
from sklearn.metrics import silhouette_score

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


twss = []
silhouette_scores = []
k_range = range(2, 9)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    twss.append(kmeans.inertia_)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(X, labels))
# Out:
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# C:\Users\likhi\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
# Plot the Elbow Method graph to find the optimal k
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(k_range, twss, marker='o', linestyle='-', color='b')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Total Within-Cluster Sum of Squares (TWSS)')
plt.title('Elbow Method for Optimal k')

plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, marker='o', linestyle='-', color='g')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal k')

plt.tight_layout()
plt.show()

# %%
# print("TWSS:", TWSS)
print("Silhouette Scores:", silhouette_scores)
# Out:
# Silhouette Scores: [0.2875152148157116, 0.28601136813339206, 0.27608490199759045, 0.2591416310298587, 0.24099249161937672, 0.22036582949911288, 0.22618410826814064]

# %% [markdown]
# <h1>GaussianMixture</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

optimal_n_clusters = 4
data_preprocessed = df  # Assuming data_preprocessed is a pandas DataFrame

# Create a Gaussian Mixture Model with a specified number of components (optimal_n_clusters + 2)
gmm = GaussianMixture(n_components=optimal_n_clusters, random_state=0)
gmm.fit(data_preprocessed)

# Predict the cluster assignments for each data point
cluster_assignments = gmm.predict(data_preprocessed)

# Calculate the silhouette score
silhouette_avg = silhouette_score(data_preprocessed, cluster_assignments)
print(f'Silhouette Score: {silhouette_avg:.2f}')

# Define custom colors for clusters
custom_colors = ['red', 'green', 'blue', 'purple']  # Add more colors if needed

# Plot the data points with custom cluster colors
plt.figure(figsize=(10, 7))
cluster_colors = [custom_colors[label] for label in cluster_assignments]
plt.scatter(data_preprocessed['Age at Diagnosis'], data_preprocessed['Fever Duration'], marker='.', s=50, lw=0, alpha=0.7, c=cluster_colors, edgecolor='k')

# Set plot labels and title
plt.xlabel('Age at Diagnosis')
plt.ylabel('Fever Duration')
plt.title(f'GMM Clustering with {optimal_n_clusters} Clusters (Silhouette Score: {silhouette_avg:.2f})')

# Show the plot
plt.show()
# Out:
# Silhouette Score: 0.26

# %% [markdown]
# <h1>DBSCAN</h1>

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.15,
                            random_state=0)

X = StandardScaler().fit_transform(X[:1000])

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=15).fit(X[:1000])
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_



# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt
# %matplotlib inline

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 0
# Homogeneity: 1.000
# Completeness: 1.000
# V-measure: 1.000
# Adjusted Rand Index: 1.000
# Adjusted Mutual Information: 1.000
# Silhouette Coefficient: 0.868

# %%
print("Silhouette Score for DBSCAN: %0.2f" % metrics.silhouette_score(X[:2752], labels))
# Out:
# Silhouette Score for DBSCAN: 0.87

# %%
A = df
print(A.shape)
# Out:
# (2752, 13)

# %% [markdown]
# ## Hierarchy cluster

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score, davies_bouldin_score


data = X
df = pd.DataFrame(data)

# Perform hierarchical clustering
n_clusters = 2  # Number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)
cluster_labels = clustering.fit_predict(df)

# Calculate linkage matrix and plot the dendrogram
linkage_matrix = linkage(df, method='ward')
plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix, orientation='top', labels=cluster_labels, distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# Calculate silhouette score and Davies-Bouldin index
silhouette_avg = silhouette_score(df, cluster_labels)
davies_bouldin = davies_bouldin_score(df, cluster_labels)

print(f'Silhouette Score: {silhouette_avg:.2f}')
print(f'Davies-Bouldin Index: {davies_bouldin:.2f}')
# Out:
# Silhouette Score: 0.64
# Davies-Bouldin Index: 0.53
